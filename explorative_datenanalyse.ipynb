# %%
from dotenv import load_dotenv
import os
import pandas as pd
from sqlalchemy import create_engine

load_dotenv()
# Out:
# True

# %%
db_url = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/postgres"
engine = create_engine(db_url)


sql_query = """
    SELECT time, olr, name, length, speed, speeduncapped, freeflow, jamfactor, confidence, traversability, subsegments, day_of_week, is_peak_hour, time_to_traverse, congestion_level, is_anomaly
    FROM diu.traffic_data;
"""
traffic_data = pd.read_sql(sql_query, engine)

# %%
traffic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436925 entries, 0 to 436924
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   time              436925 non-null  datetime64[ns, UTC]
#  1   olr               436925 non-null  object
#  2   name              427112 non-null  object
#  3   length            436925 non-null  int64
#  4   speed             414692 non-null  float64
#  5   speeduncapped     414692 non-null  float64
#  6   freeflow          436925 non-null  float64
#  7   jamfactor         436925 non-null  float64
#  8   confidence        414692 non-null  float64
#  9   traversability    436925 non-null  object
#  10  subsegments       215051 non-null  object
#  11  day_of_week       436342 non-null  float64
#  12  is_peak_hour      436342 non-null  object
#  13  time_to_traverse  414141 non-null  float64
#  14  congestion_level  436342 non-null  object
#  15  is_anomaly        436342 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(7), int64(1), object(7)
# memory usage: 53.3+ MB

# %%
traffic_data.describe()
# Out:
#               length          speed  speeduncapped       freeflow  \
# count  424378.000000  402779.000000  402779.000000  424378.000000
# mean     3999.979888      16.730117      16.940686      16.907105
# std      3563.142465       7.891661       8.159425       6.169363
# min        11.000000       0.277778       0.277778       2.777778
# 25%       968.000000      11.944445      11.944445      11.944445
# 50%      3075.000000      15.000000      15.000000      16.111110
# 75%      6246.000000      20.833334      21.388890      20.833334
# max     15182.000000      36.111110      47.222225      29.166668
#
#            jamfactor     confidence    day_of_week  time_to_traverse
# count  424378.000000  402779.000000  424378.000000     402779.000000
# mean        1.220472       0.939379       3.493979        246.840192
# std         2.472936       0.075843       1.910180        244.454095
# min         0.000000       0.700000       0.000000          0.792000
# 25%         0.000000       0.910000       2.000000         58.079995
# 50%         0.100000       0.980000       4.000000        144.747697
# 75%         1.200000       0.990000       5.000000        377.999974
# max        10.000000       0.990000       6.000000       3564.719715

# %%
traffic_data.head()
# Out:
#                               time  \
# 0 2024-12-19 07:44:21.632000+00:00
# 1 2024-12-27 20:00:48.505000+00:00
# 2 2024-12-27 17:00:48.359000+00:00
# 3 2024-12-27 17:00:48.359000+00:00
# 4 2024-12-28 02:20:48.509000+00:00
#
#                                                  olr  \
# 0  CD0BEAA5OAYYECTyQQAJBQQCAuQACgUEAqx8APcBANcACQ...
# 1  CCoBEAAmJQYWPiT7GQAJBQQBAk8ACgUEAZ8uABVt/NUACQ...
# 2  CCkBEAAlJAYGeiT1zQAJBQQAAdYACgUEAKhjAO2iDaEACQ...
# 3  CCgBEAAkIwYTOyUAYQAJBQQBAwAACgQDAQsAAAAACgAJBQ...
# 4  CCkBEAAlJAYXkiTxsQAJBQQAASEACgUEALcaABT0EnkACQ...
#
#                               name  length      speed  speeduncapped  \
# 0  Anschluss B61/Bielefeld-Zentrum    7660  13.888889      13.888889
# 1                          Ostring    3539  14.444445      14.444445
# 2                       Steinhagen    5227  35.277780      35.277780
# 3                        Bielefeld      11   6.388889       6.388889
# 4                    Bielefeld-Ost    7071  23.333334      23.333334
#
#     freeflow  jamfactor  confidence traversability  \
# 0  16.388890        1.4        0.99           open
# 1  14.722222        0.1        0.99           open
# 2  29.166668        0.0        0.99           open
# 3  10.555556        3.0        0.99           open
# 4  28.611113        2.7        0.99           open
#
#                                          subsegments  day_of_week  \
# 0  [{'speed': 15.833334, 'length': 4861, 'freeFlo...            4
# 1                                               None            5
# 2                                               None            5
# 3                                               None            5
# 4                                               None            6
#
#    is_peak_hour  time_to_traverse congestion_level  is_anomaly
# 0          True        551.519996              Low       False
# 1         False        245.007683              Low       False
# 2          True        148.166920              Low       False
# 3          True          1.721739         Moderate        True
# 4         False        303.042848              Low       False

# %%
numerical_columns = ['speed', 'speeduncapped', 'freeflow', 'jamfactor', 'confidence', 'time_to_traverse']
statistics = (
    traffic_data
    .groupby('olr')[numerical_columns]
    .agg(['mean', 'std', 'min', lambda x: x.quantile(0.25), 'median', lambda x: x.quantile(0.75), 'max'])
)


statistics.columns = ['_'.join(col).strip() for col in statistics.columns.values]
statistics.reset_index(inplace=True)
statistics
# Out:
#                                                    olr  speed_mean  speed_std  \
# 0    CCgBEAAkIwYJ/CT21gAJBQQEA3gACgQDBEsA/9H/zQAJBQ...    1.661706   0.311089
# 1    CCgBEAAkIwYKUiT6OgAJBQQBA7wACgQDAUsA/5P//wAJBQ...    0.833333   0.000000
# 2    CCgBEAAkIwYOoiT9OwAJBQQCAu4ACgQDAiwA/9gAHAAJBQ...   10.076958   1.733994
# 3    CCgBEAAkIwYP7iT9YwAJBQQEAwYACgQDBCAAAAcAHAAJBQ...    1.314815   0.426041
# 4    CCgBEAAkIwYQICT+eQAJBQQBAlcACgQDAUMAAFL/3wAJBQ...    7.489167   2.426333
# ..                                                 ...         ...        ...
# 308  CD0BEAA5OAYcxyUACAAJBQQCA28ACgUEAoNjAAEuAAQACQ...    3.333334   0.000000
# 309  CD0BEAA5OAYlZiUFFQAJBQQCA44ACgUEApkiAOQ1/U0ACQ...   13.743477   1.337370
# 310  CDsBEAA3NgYYsCT6ggAJBQQEA48ACgQDBAoAAEH/+gAJBQ...    0.771605   0.122488
# 311  CGIBEABeXQX7NyUHiwAJBQQCAykACgQDAmIABGwEYQAJBQ...   14.848143   1.055523
# 312  CGMBEABfXgYWqiURlgAJBQQCA6AACgUEAoZqAP9n/yMACQ...   14.646585   1.125319
#
#      speed_min  speed_<lambda_0>  speed_median  speed_<lambda_1>  speed_max  \
# 0     1.111111          1.388889      1.666667          1.944444   2.222222
# 1     0.833333          0.833333      0.833333          0.833333   0.833333
# 2     3.611111          8.611112     10.000000         11.111112  13.888889
# 3     0.555556          1.111111      1.388889          1.666667   1.944444
# 4     1.944444          5.833334      7.222222         10.000000  13.888889
# ..         ...               ...           ...               ...        ...
# 308   3.333334          3.333334      3.333334          3.333334   3.333334
# 309   9.444445         13.055556     13.888889         14.722222  16.111110
# 310   0.555556          0.833333      0.833333          0.833333   0.833333
# 311  11.111112         14.166667     15.000000         15.833334  16.666668
# 312   9.444445         13.888889     14.722222         15.555556  16.666668
#
#      speeduncapped_mean  speeduncapped_std  ...  confidence_median  \
# 0              1.661706           0.311089  ...               0.97
# 1              0.833333           0.000000  ...               0.89
# 2             10.097770           1.789326  ...               0.84
# 3              1.314815           0.426041  ...               0.96
# 4              7.491807           2.434549  ...               0.90
# ..                  ...                ...  ...                ...
# 308            3.333334           0.000000  ...               0.94
# 309           13.753883           1.359262  ...               0.98
# 310            0.771605           0.122488  ...               0.95
# 311           14.848919           1.057013  ...               0.93
# 312           14.646740           1.125617  ...               0.93
#
#      confidence_<lambda_1>  confidence_max  time_to_traverse_mean  \
# 0                   0.9725            0.99              46.911350
# 1                   0.8900            0.89              91.199993
# 2                   0.9200            0.99               4.509364
# 3                   0.9700            0.98              27.049712
# 4                   0.9600            0.99              10.160769
# ..                     ...             ...                    ...
# 308                 0.9400            0.94             210.599989
# 309                 0.9900            0.99             629.747861
# 310                 0.9500            0.97             155.999988
# 311                 0.9700            0.99            1027.919453
# 312                 0.9700            0.99            1042.162725
#
#      time_to_traverse_std  time_to_traverse_min  time_to_traverse_<lambda_0>  \
# 0                9.866132             33.749999                    38.571427
# 1                0.000000             91.199993                    91.199993
# 2                0.868432              3.168000                     3.960000
# 3               12.492285             15.942857                    18.600000
# 4                4.174483              4.824000                     6.700000
# ..                    ...                   ...                          ...
# 308              0.000000            210.599989                   210.599989
# 309             66.254340            531.744864                   581.909443
# 310             30.955288            140.399989                   140.399989
# 311             76.700388            910.919927                   958.863118
# 312             85.041436            910.139927                   975.149972
#
#      time_to_traverse_median  time_to_traverse_<lambda_1>  \
# 0                  44.999999                    53.999996
# 1                  91.199993                    91.199993
# 2                   4.400000                     5.109677
# 3                  22.319998                    27.899998
# 4                   9.276923                    11.485714
# ..                       ...                          ...
# 308               210.599989                   210.599989
# 309               616.823995                   656.195722
# 310               140.399989                   140.399989
# 311              1012.133333                  1071.670563
# 312              1030.347185                  1092.167991
#
#      time_to_traverse_max
# 0               67.499995
# 1               91.199993
# 2               12.184615
# 3               55.799996
# 4               34.457142
# ..                    ...
# 308            210.599989
# 309            907.094064
# 310            210.599983
# 311           1366.379891
# 312           1606.129317
#
# [313 rows x 43 columns]
